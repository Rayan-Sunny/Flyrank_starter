# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayan-Sunny/Flyrank_starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Rayan-Sunny/Flyrank_starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Lane 2: Refresh/Content Opportunity Scoring.*
# As an ML student, this feels like the most practical lane to start with. The goal is clear: build a model that sorts web pages by which ones need a refresh first. Instead of sifting through thousands of URLs by hand, this helps a content team quickly focus on the pages that actually need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **The Question:** Which pages are losing search performance and need a content refresh first?
#
# **The Decision & Action:** Content editors use the ranked list to decide which pages to inspect and rewrite each week.
#
# **Cost of a Wrong Call:**
# * False Positive: A reviewer wastes 20 minutes editing a healthy page.
# * False Negative: A dying page keeps losing search traffic unnoticed.
#
# **Why ML Helps:** Scanning thousands of URLs manually isn't realistic;
#
# ML catches dropping trends across impressions_90d and avg_position much faster than manual checks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The fixed baseline rules only get 12 of their top 50 picks right **(Precision@50 = 0.240).**
#
# A simple Decision Tree model jumps to 27 of 50 right **(Precision@50 = 0.540)**, proving ML can easily beats fixed rules.
#
# The starter dataset gives us approx 30,000 anonymized page records to train and test on.

# %%
import pandas as pd

# Load starter CSV
csv_url = "https://raw.githubusercontent.com/Rayan-Sunny/Flyrank_starter/refs/heads/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(csv_url)

total_pages = len(df)
declining = (df['trend_direction'] == 'down').sum()

print(f"Total pages: {total_pages:,}")
print(f"Declining pages: {declining:,} ({(declining/total_pages)*100:.1f}%)")
# Out:
# Total pages: 30,000
# Declining pages: 16,262 (54.2%)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# 4. Careful words: what I can and can't claim
#
# **What I CAN claim:** A decision-support tool that ranks pages by risk of performance drop based on observed metrics.
#
# **What I CANNOT claim:** Causal proof that updating a page guarantees a recovery, or any claim about predicting Google's internal algorithm.  *

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
